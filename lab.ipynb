# %%
from src import data_loader
from src import pitcher_attributes, pitcher_rating

#display(data_loader.get_fangraphs(2025))
#a = data_loader.get_player("Shohei", "Ohtani")
#print(a)
#display(pitcher_attributes.get_war(int(a), 2025))

#display(pitcher_attributes.get_whif(data_loader.get_season_pitching(2025)))
display(data_loader.get_command(2024))
# Out:
#              pitcher pitch_type     n   naive_in  inferred_in
# 0        A.J. Minter        ALL   504  10.331579     9.363668
# 1        A.J. Minter         CH    93  12.219323     9.903026
# 2        A.J. Minter         FC   170  10.843077     9.971207
# 3        A.J. Minter         FF   241   9.783790     8.671470
# 4           A.J. Puk        ALL  1119  10.677183     9.824464
# ...              ...        ...   ...        ...          ...
# 4647  Zebby Matthews         CH    49  16.348612    13.766050
# 4648  Zebby Matthews         CU    32  11.930758     9.631990
# 4649  Zebby Matthews         FC    88   8.032285     8.725533
# 4650  Zebby Matthews         FF   243   9.044456     8.549899
# 4651  Zebby Matthews         SL   133  11.023784     9.293098
#
# [4652 rows x 5 columns]
