# %%
from src import data_loader
from src import pitcher_attributes, pitcher_rating

#display(data_loader.get_fangraphs(2025))
#a = data_loader.get_player("Shohei", "Ohtani")
#print(a)
#display(pitcher_attributes.get_war(int(a), 2025))

#display(pitcher_attributes.get_whif(data_loader.get_season_pitching(2025)))
display(pitcher_rating.whiff(data_loader.get_season_pitching(2025), 'Chris', 'Sale'))
display(pitcher_attributes.calculate_woba( 2025, data_loader.get_season_pitching(2025)))
# Out:
# np.float64(81.2802)
#            player_name   game_date  hbp  bb  ibb  1b  2b  3b  hr   ab  sf  \
# 346        Smith, Cade  2025-10-01    6  21    3  29  21   1   4  281   2
# 755      Hurter, Brant  2025-10-01   11  27    3  45   8   0   5  239   1
# 1190      Melton, Troy  2025-10-01    1  16    1  20   6   0   8  166   1
# 721       Junis, Jakob  2025-10-01    4  19    2  46  11   2   5  251   2
# 560     Finnegan, Kyle  2025-10-01    1  19    2  30   8   3   4  209   3
# ...                ...         ...  ...  ..  ...  ..  ..  ..  ..  ...  ..
# 317   Winckowski, Josh  2025-04-23    1   5    0   9   2   0   0   44   2
# 3631     Leclerc, José  2025-04-22    0   5    0   7   2   1   3   41   0
# 1969     Anderson, Ian  2025-04-22    0   7    1  13   2   0   2   44   0
# 77      Spiers, Carson  2025-04-19    1   7    0   8   2   0   3   50   1
# 100     Steele, Justin  2025-04-07    1   4    0  11   2   0   3   70   0
#
#           wOBA  wOBA_score
# 346   0.255283   92.175274
# ...
