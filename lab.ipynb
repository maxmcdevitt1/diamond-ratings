# %%
from src import data_loader
from src import pitcher_attributes, pitcher_rating

#display(data_loader.get_fangraphs(2025))
#a = data_loader.get_player("Shohei", "Ohtani")
#print(a)
#display(pitcher_attributes.get_war(int(a), 2025))

#display(pitcher_attributes.get_whif(data_loader.get_season_pitching(2025)))
display(pitcher_rating.whiff(data_loader.get_season_pitching(2025), 'Chris', 'Sale'))
display(pitcher_attributes.calculate_woba( 2025, data_loader.get_season_pitching(2025)))
# Out:
# np.float64(81.5758)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[1], line 11
#       7 #display(pitcher_attributes.get_war(int(a), 2025))
#       8
#       9 #display(pitcher_attributes.get_whif(data_loader.get_season_pitching(2025)))
#      10 display(pitcher_rating.whiff(data_loader.get_season_pitching(2025), 'Chris', 'Sale'))
# ---> 11 display(pitcher_attributes.calculate_woba('Sale, Chris', 2025, data_loader.get_season_pitching(2025)))
#
# TypeError: calculate_woba() takes 2 positional arguments but 3 were given
