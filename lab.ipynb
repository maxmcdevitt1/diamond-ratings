# %%
from src    import data_loader
from src import pitcher_attributes, pitcher_rating, batter_attributes
import main
display(main.main()[0])
display(main.main()[1])
# Out:
#     year        player_name  batter Power Contact    WAR
# 0   2026      Riley, Austin  663586  70.0    12.0  69.36
# 1   2026    Hicklen, Brewer  676551  None    None  32.46
# 2   2026   Keirsey, Dashawn  680577  None    None  48.91
# 3   2026     Smith, Dominic  642086  28.0    58.0  24.21
# 4   2026     Baldwin, Drake  686948  82.0    89.0  94.78
# 5   2026      Kim, Ha-seong  673490  None    None   3.03
# 6   2026       Farmer, Kyle  571657  None    None  26.52
# 7   2026        Olson, Matt  621566  96.0    59.0  96.24
# 8   2026    Dubón, Mauricio  643289  18.0    94.0  87.74
# 9   2026    Harris, Michael  671739  83.0    94.0  97.09
# 10  2026  Yastrzemski, Mike  573262  51.0    36.0  71.97
# 11  2026      Albies, Ozzie  645277  30.0    46.0  78.40
# 12  2026      Acuña, Ronald  660670  87.0    67.0  83.13
# 13  2026       Murphy, Sean  669221  None    None  45.15
#     year  pitcher  movement  velocity control    war   woba    whiff
# ...
