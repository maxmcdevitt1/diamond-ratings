# %%
from src import data_loader
from src import pitcher_attributes

display(data_loader.get_fangraphs(2025))
a = data_loader.get_player("Shohei", "Ohtani")
print(a)
display(pitcher_attributes.get_war(int(a), 2025))
# Out:
#     Throws  xMLBAMID                                               Name  \
# 0        L    669373  <a href="statss.aspx?playerid=22267&position=P...
# 1        R    694973  <a href="statss.aspx?playerid=33677&position=P...
# 2        L    650911  <a href="statss.aspx?playerid=20778&position=P...
# 3        L    676979  <a href="statss.aspx?playerid=27463&position=P...
# 4        R    657277  <a href="statss.aspx?playerid=17995&position=P...
# ..     ...       ...                                                ...
# 868      R    670102  <a href="statss.aspx?playerid=20548&position=P...
# 869      L    650893  <a href="statss.aspx?playerid=17490&position=P...
# 870      R    643338  <a href="statss.aspx?playerid=15552&position=P...
# 871      L    641482  <a href="statss.aspx?playerid=17874&position=P...
# 872      R    687134  <a href="statss.aspx?playerid=26419&position=P...
#
#                                                   Team  Season   Age     AgeR  \
# ...
