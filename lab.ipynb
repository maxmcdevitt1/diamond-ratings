# %%
from src    import data_loader
from src import pitcher_attributes, pitcher_rating, batter_attributes

#display(data_loader.get_fangraphs(2025))
#a = data_loader.get_player("Shohei", "Ohtani")
#print(a)
#display(pitcher_attributes.get_war(int(a), 2025))

#display(pitcher_attributes.get_whif(data_loader.get_season_pitching(2025)))
#display(data_loader.get_batting())
display(batter_attributes.get_contact(2025))
display(data_loader.get_player('Ronald', 'Acuna jr'))
display(data_loader.get_season_pitching(2024))
display(data_loader.get_batting_year(2024))
# Out:
#      last_name, first_name  year  player_id  contact_score  batting_avg  \
# 2648     Maldonado, Martín  2025     455117           0.02        0.204
# 2649       Solano, Donovan  2025     456781           0.35        0.247
# 2650     McCutchen, Andrew  2025     457705           0.49        0.239
# 2651        Turner, Justin  2025     457759           0.37        0.219
# 2652       Santana, Carlos  2025     467793           0.21        0.219
# ...                    ...   ...        ...            ...          ...
# 3036            Shaw, Matt  2025     807713           0.38        0.226
# 3037     Yoshida, Masataka  2025     807799           0.91        0.266
# 3038         Kim, Hyeseong  2025     808975           0.52        0.280
# 3039         Lee, Jung Hoo  2025     808982           0.93        0.266
# 3040       Williamson, Ben  2025     810938           0.61        0.253
#
#       bat_control_score  hit_score  hit_measure
# 2648           2.798982   5.343511       0.1980
# ...
