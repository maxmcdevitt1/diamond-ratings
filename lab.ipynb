# %%
from src    import data_loader
from src import pitcher_attributes, pitcher_rating, batter_attributes

display(data_loader.get_player('Matt', 'Olson'))
display(data_loader.get_player_name(621566))
# Out:
# np.int64(621566)
