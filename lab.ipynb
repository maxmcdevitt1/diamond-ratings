# %%
# %pip install -e /home/max/programming/python/ML/diamond-ratings
# Out:
# Obtaining file:///home/max/programming/python/ML/diamond-ratings
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
# ...
#   Building editable for diamond-ratings (pyproject.toml) ... done
#   Created wheel for diamond-ratings: filename=diamond_ratings-0.1.0a1-0.editable-py3-none-any.whl size=4847 sha256=dfd92bd44bda0aa05518c4e2bef858700734ad17da845262c96578c0bd5651a2
#   Stored in directory: /tmp/pip-ephem-wheel-cache-4edm_eco/wheels/75/50/5d/c32077a13b4ac4c7dc46422220908ed18a82ef7f79c5ccadfb
# Successfully built diamond-ratings
# ...
#   Attempting uninstall: diamond-ratings
#     Found existing installation: diamond-ratings 0.1.0a1
#     Uninstalling diamond-ratings-0.1.0a1:
#       Successfully uninstalled diamond-ratings-0.1.0a1
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import main
import pathlib
import pandas as pd

#path = pathlib.Path('data/')
#display(pd.DataFrame(pd.read_parquet(path/'batter.parquet')))
#display(pd.DataFrame(pd.read_parquet(path/'pitcher.parquet')))

#batters, pitchers, score = main.main()
#display(batters)
#display(pitchers)
#display(score)
# Out:
#      year       player_name  batter  Power  Contact    WAR  \
# 0    2026   Carroll, Corbin  682998   88.0     51.0  97.94
# 1    2026   Moreno, Gabriel  672515   61.0    100.0  99.27
# 2    2026  Perdomo, Geraldo  672695   13.0     80.0  97.27
# 3    2026  Vargas, Ildemaro  545121   24.0     85.0  77.49
# 4    2026     Mccann, James  543510   60.0     56.0  58.56
# ..    ...               ...     ...    ...      ...    ...
# 403  2026       Wood, James  695578   98.0     69.0  95.02
# 404  2026     Vivas, Jorbit  678391    8.0     56.0  75.67
# 405  2026        Tena, José  677588   66.0     13.0   8.98
# 406  2026     Ruiz, Keibert  660688   41.0     90.0  86.83
# 407  2026      Nuñez, Nasim  683083    2.0     25.0  73.79
#
#                      team  team_id
# 0    Arizona Diamondbacks      109
# 1    Arizona Diamondbacks      109
# 2    Arizona Diamondbacks      109
# 3    Arizona Diamondbacks      109
# 4    Arizona Diamondbacks      109
# ..                    ...      ...
# ...
