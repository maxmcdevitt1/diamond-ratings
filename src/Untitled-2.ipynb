# %%
from src import data_loader
df = data_loader.get_command(2026)
first = 'Chris'
last = 'Sale'
average = df.copy()
#average = average.groupby('player_name')
average = average[average['pitch_type'] == 'ALL']
a = average['inferred_in'].median()
display(a)
# Out:
# np.float64(9.917947101559523)
