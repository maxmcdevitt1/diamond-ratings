# %%
# %run data_loader

# %%
import data_loader
#df = data_loader.get_pitcher_dataframe("Chris", "Sale", "2025-04-1", "2025-10-01")
#print(df["description"].unique())
#df = data_loader.get_all_pitchers()
display(data_loader.get_year())
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 import pitcher_attributes
#       2 #df = data_loader.get_pitcher_dataframe("Chris", "Sale", "2025-04-1", "2025-10-01")
#       3 #print(df["description"].unique())
#       4 #df = data_loader.get_all_pitchers()
#
# File ~/programming/python/ML/player_rating/src/pitcher_attributes.py:3
#       1 import pandas as pd
#       2 import numpy as np
# ----> 3 from .woba_weights import WOBA_WEIGHTS
#       7 def velocity(season):
#       8     fastballs = ('SI', 'FF', 'FC')
#
# ImportError: attempted relative import with no known parent package
