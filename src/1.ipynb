# %%
# %run data_loader
# Out:
# 519242
# Gathering Player Data

# %%
import pitcher_attributes, data_loader
#df = data_loader.get_pitcher_dataframe("Chris", "Sale", "2025-04-1", "2025-10-01")
#print(df["description"].unique())
#df = data_loader.get_all_pitchers()
display(pitcher_attributes.velocity())
# Out:
# 519242
# Gathering Player Data
#    pitch_type   game_date  release_speed  release_pos_x  release_pos_z  \
# 48         FF  2026-09-11           93.2           2.83           5.06
#
#     player_name  batter  pitcher     events    description  ...  \
# 48  Sale, Chris  592663   519242  field_out  hit_into_play  ...
#
#     api_break_x_batter_in  arm_angle  attack_angle  attack_direction  \
# 48                  -1.33       <NA>     18.614876          -5.19117
#
#     swing_path_tilt intercept_ball_minus_batter_pos_x_inches  \
# 48        35.340527                                38.428843
#
#    intercept_ball_minus_batter_pos_y_inches total_swings misses    whiff
# 48                                33.751058         1206  363.0  30.0995
#
# [1 rows x 122 columns]
